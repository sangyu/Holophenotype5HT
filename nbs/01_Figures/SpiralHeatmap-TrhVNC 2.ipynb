# %%
import dabest
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import esploco.plotTools as plotTools
plotTools.setFont('Helvetica', 9)

# %matplotlib inline
w1118 = pd.read_csv('w1118.csv')
TrhCsCh = pd.read_csv('TrhCsCh_ele.csv').sort_values(by = 'Light')
R50CsCh = pd.read_csv('R50CsCh_ele.csv').sort_values(by = 'Light')
TrhACR = pd.read_csv('TrhACRRound2_ele.csv').sort_values(by = 'Light')
R50ACR = pd.read_csv('R50ACRRound2_ele.csv').sort_values(by = 'Light')
VNCCsCh = pd.read_csv('TrhVNCCsCh_ele.csv').sort_values(by = 'Status')
SXVNC1CsCh = pd.read_csv('SXVNC1CsCh_ele.csv').sort_values(by = 'Status')
SXVNC2CsCh = pd.read_csv('SXVNC2CsCh_ele.csv').sort_values(by = 'Status')
RLTG = pd.read_csv('RLTG_ele.csv').sort_values(by = 'Status')
TLRG = pd.read_csv('TLRG_ele.csv').sort_values(by = 'Status')
TrhGal4TshGal80CsCh = pd.read_csv('TrhGal4TshGal80CsCh_ele.csv').sort_values(by = 'Status')
Trh4CsCh = pd.read_csv('Trh4CsCh_ele.csv').sort_values(by = 'Status')
Trh4TshGal80CsCh= pd.read_csv('Trh4TshGal80CsChrimson_ele.csv').sort_values(by = 'Status')
NPFCsCh= pd.read_csv('NPFCsCh_ele.csv').sort_values(by = 'Status')
AKH3CsCh= pd.read_csv('AKH3CsCh_ele.csv').sort_values(by = 'Status')
AKH2ACR= pd.read_csv('AKH2ACR_ele.csv').sort_values(by = 'Status')
Dilp2CsCh= pd.read_csv('Dilp2CsCh_ele.csv').sort_values(by = 'Status')
Trh2CsCh= pd.read_csv('Trh2CsChRound2_ele.csv').sort_values(by = 'Status')
Trh1CsCh= pd.read_csv('Trh1CsCh_ele.csv').sort_values(by = 'Status')
Trh3CsCh= pd.read_csv('Trh3CsChRound2_ele.csv').sort_values(by = 'Status')


w1118['Starvation'] = w1118['Starvation'].astype(str)
TrhCsCh['Starvation'] = TrhCsCh['Starvation'].astype(str)
R50CsCh['Starvation'] = R50CsCh['Starvation'].astype(str)
TrhACR['Starvation'] = TrhACR['Starvation'].astype(str)
VNCCsCh['Starvation'] = VNCCsCh['Starvation'].astype(str)
SXVNC1CsCh['Starvation'] = SXVNC1CsCh['Starvation'].astype(str)
SXVNC2CsCh['Starvation'] = SXVNC2CsCh['Starvation'].astype(str)
RLTG['Starvation'] = RLTG['Starvation'].astype(str)
TLRG['Starvation'] = TLRG['Starvation'].astype(str)
TrhGal4TshGal80CsCh['Starvation'] = TrhGal4TshGal80CsCh['Starvation'].astype(str)
Trh4CsCh['Starvation'] = Trh4CsCh['Starvation'].astype(str)
Trh4TshGal80CsCh['Starvation'] = Trh4TshGal80CsCh['Starvation'].astype(str)
NPFCsCh['Starvation'] = NPFCsCh['Starvation'].astype(str)
AKH3CsCh['Starvation'] = AKH3CsCh['Starvation'].astype(str)
AKH2ACR['Starvation'] = AKH2ACR['Starvation'].astype(str)
Dilp2CsCh['Starvation'] = Dilp2CsCh['Starvation'].astype(str)
Trh2CsCh['Starvation'] = Trh2CsCh['Starvation'].astype(str)
Trh1CsCh['Starvation'] = Trh1CsCh['Starvation'].astype(str)
Trh3CsCh['Starvation'] = Trh3CsCh['Starvation'].astype(str)

starvationhrs = w1118.Starvation.unique()
vectorselection = ['Volume', 'Feed Speed', 'Meal Size', 'Meal Duration', 'Duration', 'Count', 'Height', 
    'Food Port Occupancy', 'Ctrl Port Occupancy','Latency', 'Speed', 'Prefeed Speed', 'Duringfeed Speed',  'Postfeed Speed', 'Duringfeed Speed Ratio',
                   'Perifeed Speed Ratio',  
                   'Falls',
                  ]

# %%
VNCCsCh
# Out:
#                          ChamberID                     countLogID  \
# 0     2022-05-12_17-23-39_Chamber1   2022-05-12_17-23-37_Ch1_Obj1
# 129   2023-07-13_16-18-29_Chamber2   2023-07-13_16-18-27_Ch2_Obj1
# 130  2023-07-13_16-18-29_Chamber20  2023-07-13_16-18-27_Ch20_Obj1
# 132  2023-07-13_16-18-29_Chamber26  2023-07-13_16-18-27_Ch26_Obj1
# 133  2023-07-13_16-18-29_Chamber27  2023-07-13_16-18-27_Ch27_Obj1
# ..                             ...                            ...
# 57   2022-05-20_12-26-32_Chamber12  2022-05-20_12-26-29_Ch12_Obj1
# 136   2023-07-13_16-18-29_Chamber3   2023-07-13_16-18-27_Ch3_Obj1
# 60   2022-05-20_12-26-32_Chamber15  2022-05-20_12-26-29_Ch15_Obj1
# 39   2022-05-16_17-09-00_Chamber20  2022-05-16_17-08-56_Ch20_Obj1
# 157  2023-07-19_14-55-40_Chamber30  2023-07-19_14-55-36_Ch30_Obj1
#
#                                       AviFile       ExperimentState  \
# 0     FeedEvent_0_2022-05-12_17-24-14.904.avi  Red LED 2.8V 35uWmm2
# ...

# %% [markdown]
# ### w1118 contrasts

# %%
w1118base = w1118.loc[w1118['Starvation'] == '0']
w1118base1 = w1118.loc[w1118['Starvation'] == '0']
w1118base1['Starvation'] = '00'
w1118base = w1118base.append(w1118base1)


contrasts = []
for i in range(0, len(starvationhrs)):

    contrast_vector = [None]*len(vectorselection)
    for j in range(len(vectorselection)):
        if i ==0:
            contrast_vector[j] = dabest.load(w1118base, x = 'Starvation', y = vectorselection[j], idx = ('0', '00'))
        else:
            contrast_vector[j] = dabest.load(w1118, x = 'Starvation', y = vectorselection[j], idx = ('0', starvationhrs[i]))
    contrasts.append(contrast_vector)
# Out:
# <ipython-input-6-ad7732c3efe7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w1118base1['Starvation'] = '00'
# <ipython-input-6-ad7732c3efe7>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   w1118base = w1118base.append(w1118base1)

# %% [markdown]
# ### transgenics contrasts

# %%
datasets = [TrhACR, TrhCsCh, R50CsCh, R50ACR, ]


contrastsTrans = []
for i in range(len(datasets)):
    contrast_vector = [None]*len(vectorselection)
    for j in range(len(vectorselection)):
        contrast_vector[j] = dabest.load(datasets[i], x = ['Light', 'Genotype'], 
                                         experiment = 'Status', delta2 = True, 
                                         y = vectorselection[j], 
#                                          x1_level=['Ctrl', 'Test'], 
                                         experiment_label=['Ctrl', 'Test'])
    contrastsTrans.append(contrast_vector)

# %%
metadatasets = [NPFCsCh, AKH3CsCh, AKH2ACR, Dilp2CsCh]

contrastsMeta = []
for i in range(len(metadatasets)):
    contrast_vector = [None]*len(vectorselection)
    for j in range(len(vectorselection)):
        contrast_vector[j] = dabest.load(metadatasets[i], x = 'Status',
                                         y = vectorselection[j], 
                                         idx=('Ctrl', 'Test'),)
    contrastsMeta.append(contrast_vector)

# %%
splitdatasets = [  VNCCsCh, SXVNC1CsCh, SXVNC2CsCh]
# splitdatasets = [ TLRG, RLTG, TrhGal4TshGal80CsCh, VNCCsCh, SXVNC1CsCh, SXVNC2CsCh]

contrastsSplits = []
for i in range(len(splitdatasets)):
    contrast_vector = [None]*len(vectorselection)
    for j in range(len(vectorselection)):
        contrast_vector[j] = dabest.load(splitdatasets[i], x = 'Status',
                                         y = vectorselection[j], 
                                         idx=('Ctrl', 'Test'),)
    contrastsSplits.append(contrast_vector)

# %%
bashdatasets = [Trh1CsCh, Trh2CsCh, Trh3CsCh, Trh4CsCh, Trh4TshGal80CsCh,]

contrastsBash = []
for i in range(len(bashdatasets)):
    contrast_vector = [None]*len(vectorselection)
    for j in range(len(vectorselection)):
        contrast_vector[j] = dabest.load(bashdatasets[i], x = 'Status',
                                         y = vectorselection[j], 
                                         idx=('Ctrl', 'Test'),)
    contrastsBash.append(contrast_vector)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 7
#       5 contrast_vector = [None]*len(vectorselection)
#       6 for j in range(len(vectorselection)):
# ----> 7     contrast_vector[j] = dabest.load(bashdatasets[i], x = 'Status',
#       8                                      y = vectorselection[j],
#       9                                      idx=('Ctrl', 'Test'),)
#      10 contrastsBash.append(contrast_vector)
#
# File /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_api.py:77, in load(data, idx, x, y, paired, id_col, ci, resamples, random_seed, proportional, delta2, experiment, experiment_label, x1_level, mini_meta)
#      11 '''
#      12 Loads data in preparation for estimation statistics.
#      13
#    (...)
#      73 A `Dabest` object.
#      74 '''
#      75 from ._classes import Dabest
# ...

# %% [markdown]
# ### below is the function ```spiral_heatmap``` to plot a spiral heatmap from a list of list of contrasts

# %%
def sample_bootstrap(bootstrap, m, n, reverse_neg, abs_rank, chop_tail):
    bootstrap.sort() 
    chop_tail_int = int(np.ceil(len(bootstrap)*chop_tail/100))
    bootstrap = bootstrap[chop_tail_int : len(bootstrap) - chop_tail_int]
    # print(len(bootstrap))
    ranks_to_look = np.linspace(0,len(bootstrap), m * n, dtype = int)   
    ranks_to_look[0] = 1
    if np.sum(bootstrap>0)<len(bootstrap)/2:
        if reverse_neg == True:
            bootstrap = bootstrap[::-1]
    if abs_rank == True:
        bootstrap = bootstrap[np.argsort(np.abs(bootstrap))]
    long_ranks = [bootstrap[r - 1] for r in ranks_to_look]
    return long_ranks
    
def spiralize(fill, m, n):
    i = 0
    j = 0
    k = 0
    array = np.zeros((m, n))
    while m>0:
        jj = j
        ii = i
        for j in range(j, n):
            array[i, j] = fill[k]
            k += 1
        for i in range(ii+1, m):
            array[i, j] = fill[k]
            k += 1
        for j in range(n-2,jj-1,-1):
            array[i, j] = fill[k]
            k += 1
        for i in range(n-2,ii,-1):
            array[i, j] = fill[k]
            k += 1        
        m -= 1
        n -= 1
        j += 1
        if k > len(fill):
            break
        # print (array)
    return(array)

def spiral_heatmap(contrasts, n, ylabels, xlabels, sort_by = None, vmax = 3, vmin = -3, reverse_neg = True, abs_rank = False, chop_tail = 0, ax = None, delta_type = 'delta'):
    spirals = pd.DataFrame(np.zeros((len(contrasts) * n, len(contrasts[0]) * n)))
    from mpl_toolkits.axes_grid1.inset_locator import inset_axes
    if sort_by is not None:
        xlabels = [xlabels[i] for i in sort_by]
    mean_delta = pd.DataFrame(np.zeros((len(contrasts) , len(contrasts[0]))), columns = xlabels, index = ylabels)
    for i in range(len(contrasts)):
        for j in range(len(contrasts[0])):
            if sort_by is not None:
                jj = sort_by[j]
            else:
                jj = j
            if delta_type == 'delta':
                bootstrap = contrasts[i][jj].hedges_g.results.bootstraps[0]
            elif delta_type == 'deltadelta':
                bootstrap = contrasts[i][jj].delta_g.delta_delta.bootstraps_delta_delta
            long_ranks = sample_bootstrap(bootstrap, n, n, reverse_neg = reverse_neg, abs_rank = abs_rank, chop_tail = chop_tail)
            spiral = spiralize(long_ranks, n, n)
            spirals.iloc[i*n:i*n+n, j*n:j*n+n] = spiral
            mean_delta.iloc[i, j] = np.mean(long_ranks)
    if ax == None:
        f, a = plt.subplots(1, 1)
    else:
        a = ax
    sns.heatmap(spirals, cmap = 'vlag', ax = a, vmax = vmax, vmin = vmin)
    a.set_xticks(np.linspace(n/2, len(contrasts[0])*n-n/2, len(contrasts[0])))
    a.set_xticklabels(xlabels, rotation = 45, ha= 'right')
    a.set_yticks(np.linspace(n/2, len(contrasts)*n-n/2, len(contrasts)));
    a.set_yticklabels(ylabels, ha= 'right', rotation = 0)
    if ax == None:
        f.gca().set_aspect('equal')
        f.set_size_inches(len(contrasts[0])/3,  len(ylabels))
        return f, a, mean_delta
    else:
        return a, mean_delta

# %% [markdown]
# ### the number of squares drawn per cell is user defined and can be adjusted using the parameter `n`

# %%
sp21, a21, mean_delta21 = spiral_heatmap(contrasts, 21, ['baseline', '24 hr starved', '48 hr starved'], 
                           vectorselection, reverse_neg=False,  
                           abs_rank = True, chop_tail = 2.5, )
sp21_sort, a21_sort_sorted, mean_delta21_sorted = spiral_heatmap(contrasts, 21, ['baseline', '24 hr starved', '48 hr starved'], 
                           vectorselection, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], reverse_neg=False,  
                           abs_rank = True, chop_tail = 2.5, )
print(mean_delta21_sorted.columns)
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)

sp21_sort.savefig('sp_w1118_21.png', dpi = 300)
sp21_sort.savefig('sp_w1118_21.svg')
# a21_sort_sorted.set_xticks([])
sp21_sort.savefig('sp_w1118_21_noticks.png', dpi = 300)
sp21_sort.savefig('sp_w1118_21_noticks.svg')
# Out:
# Index(['Volume', 'Meal Duration', 'Meal Size', 'Duration', 'Feed Speed',
#        'Food Port Occupancy', 'Height', 'Count', 'Duringfeed Speed Ratio',
#        'Falls', 'Prefeed Speed', 'Ctrl Port Occupancy', 'Speed',
#        'Postfeed Speed', 'Perifeed Speed Ratio', 'Latency',
#        'Duringfeed Speed'],
#       dtype='object')

# %%
TrhGal4TshGal80CsCh
# Out:
#             Light                            Genotype Status  ID Starvation  \
# 0    Red Light On    w1118; tsh-gal80; uas-cschrimson   Ctrl   1         24
# 116  Red Light On                     w1118; trh-gal4   Ctrl  14         24
# 115  Red Light On    w1118; tsh-gal80; uas-cschrimson   Ctrl  13         24
# 113  Red Light On                     w1118; trh-gal4   Ctrl  11         24
# 112  Red Light On    w1118; tsh-gal80; uas-cschrimson   Ctrl  10         24
# ..            ...                                 ...    ...  ..        ...
# 110  Red Light On  trh-gal4>tsh-gal80; uas-cschrimson   Test   9         24
# 108  Red Light On  trh-gal4>tsh-gal80; uas-cschrimson   Test   6         24
# 43   Red Light On  trh-gal4>tsh-gal80; uas-cschrimson   Test  23         24
# 46   Red Light On  trh-gal4>tsh-gal80; uas-cschrimson   Test  26         24
# 89   Red Light On  trh-gal4>tsh-gal80; uas-cschrimson   Test  15         24
#
# ...

# %%
plt.rcParams['svg.fonttype'] = 'none'

spBash, aBash, mean_deltaBash = spiral_heatmap(contrastsBash, 21, ['Trh1CsCh', 'Trh2CsCh', 'Trh3CsCh', 'Trh4CsCh', 'Trh4TshGal80CsCh',], 
                         vectorselection, reverse_neg = False, abs_rank = True, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], chop_tail = 0, delta_type = 'delta')
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
aBash.set_yticklabels(['Trh1CsCh', 'Trh2CsCh', 'Trh3CsCh', 'Trh4CsCh', 'Trh4TshGal80CsCh',], rotation = 0, ha = 'right')
spBash.savefig('spBash_21.png', dpi = 300)
spBash.savefig('spBash_21.svg', dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 plt.rcParams['svg.fonttype'] = 'none'
# ----> 3 spBash, aBash, mean_deltaBash = spiral_heatmap(contrastsBash, 21, ['Trh1CsCh', 'Trh2CsCh', 'Trh3CsCh', 'Trh4CsCh', 'Trh4TshGal80CsCh',],
#       4                          vectorselection, reverse_neg = False, abs_rank = True, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], chop_tail = 0, delta_type = 'delta')
#       5 plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
#       6 aBash.set_yticklabels(['Trh1CsCh', 'Trh2CsCh', 'Trh3CsCh', 'Trh4CsCh', 'Trh4TshGal80CsCh',], rotation = 0, ha = 'right')
#
# Cell In[15], line 45, in spiral_heatmap(contrasts, n, ylabels, xlabels, sort_by, vmax, vmin, reverse_neg, abs_rank, chop_tail, ax, delta_type)
# ...

# %%
spMeta, aMeta, mean_deltaMeta = spiral_heatmap(contrastsMeta, 21, ['NPFCsCh', 'AKH3CsCh', 'AKH2ACR', 'Dilp2CsCh'], 
                         vectorselection, reverse_neg = False, abs_rank = True, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], chop_tail = 2.5, delta_type = 'delta')
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
spMeta.savefig('spMeta_21.png', dpi = 300)
spMeta.savefig('spMeta_21.svg', dpi = 300)
# Out:
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1698: UserWarning: The lower limit of the interval was in the bottom 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="lower",
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1698: UserWarning: The lower limit of the interval was in the bottom 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="lower",
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1698: UserWarning: The lower limit of the interval was in the bottom 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="lower",
# ...

# %%
plt.rcParams['svg.fonttype'] = 'none'

# spSplits, aSplits, mean_deltaSplits = spiral_heatmap(contrastsSplits, 21, ['TLRG', 'RLTG',  'TrhGal4TshGal80CsCh', 'VNCCsCh', 'SXVNC1CsCh'], 
spSplits, aSplits, mean_deltaSplits = spiral_heatmap(contrastsSplits, 21, ['VNCCsCh', 'SXVNC1CsCh', 'SXVNC2CsCh'], 
                         vectorselection, reverse_neg = False, abs_rank = True, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], chop_tail = 0, delta_type = 'delta')
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
aSplits.set_yticklabels(['VNCCsCh', 'SXVNC1CsCh', 'SXVNC2CsCh'], rotation = 0, ha = 'right')
# aSplits.set_yticklabels(['(R50 - Trh)CsCh', '(Trh - R50)CsCh','BrainTrhCsCh',  'VNCTrhCsCh', 'SXVNC1CsCh'], rotation = 0, ha = 'right')
spSplits.savefig('spSplits_21.png', dpi = 800)
spSplits.savefig('spSplits_21.svg', dpi = 600)
# Out:
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1703: UserWarning: The upper limit of the interval was in the top 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="upper",

# %%
plt.rcParams['svg.fonttype'] = 'none'

spTrans, aTrans, mean_deltaTrans = spiral_heatmap(contrastsTrans, 21, [ 'TrhACR1', 'TrhCsCh','R50CsCh', 'R50ACR1'], 
                         vectorselection, reverse_neg = False, abs_rank = True, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], chop_tail = 2.5, delta_type = 'deltadelta')
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
aTrans.set_yticklabels(['TrhACR1', 'TrhCsCh',   'R50CsCh', 'R50ACR1'], rotation = 0, ha = 'right')
spTrans.savefig('spTrans_21.png', dpi = 300)
spTrans.savefig('spTrans_21.svg', dpi = 300)
# Out:
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1703: UserWarning: The upper limit of the interval was in the top 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="upper",
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1698: UserWarning: The lower limit of the interval was in the bottom 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="lower",
# /Applications/anaconda3/envs/esplocotest/lib/python3.9/site-packages/dabest/_classes.py:1698: UserWarning: The lower limit of the interval was in the bottom 10 values. The result should be considered unstable.
#   warnings.warn(err_temp.substitute(lim_type="lower",
# ...

# %%
f, a = plt.subplots(1, 1)
f.set_size_inches(10, 5)
sns.heatmap(mean_deltaTrans, cmap = 'vlag', ax = a, vmin = -2.5, vmax = 2.5)
a.set_yticklabels(['TrhACR1', 'TrhCsCh',   'R50CsCh', 'R50ACR1'], rotation = 0, ha = 'right')
plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)
f.savefig('straight_heatmap.png', dpi = 300)

# %%
c = contrastsSplits[0][9]
f = c.hedges_g.plot(float_contrast=False, contrast_ylim=[-2.5, 2.5]);
f.savefig('split09.svg', dpi = 300)

# %% [markdown]
# ##

# %% [markdown]
# ##

# %%
c = contrastsSplits[2][5]
f = c.hedges_g.plot(float_contrast=False, contrast_ylim=[-2.5, 2.5]);
f.savefig('split25.svg', dpi = 300)

# %%
c = contrastsSplits[1][6]
f = c.hedges_g.plot(float_contrast= False, contrast_ylim=[-2.5, 2.5]);
f.savefig('split16.svg', dpi = 300)

# %%
sp5_sort, a5_sort_sorted, mean_delta5_sorted = spiral_heatmap(contrasts, 5, ['baseline', '24 hr starved', '48 hr starved'], 
                           vectorselection, sort_by = np.argsort(mean_delta21.iloc[2, :].values)[::-1], reverse_neg=False,  
                           abs_rank = True, chop_tail = 0, )

plt.gcf().subplots_adjust(left = 0.1, bottom=0.7)

a5_sort_sorted.set_xticks([])
sp5_sort.savefig('sp_w1118_5_noticks.png', dpi = 600)
sp5_sort.savefig('sp_w1118_5_noticks.svg')

# %%
import scipy
from scipy import stats
def plotcorr(x, y, ax, label = None, xlabel = None, ylabel = None):
    res = stats.linregress(x, y)
    sns.regplot(x = x, y = y, ax = ax, label=label+ f" | rsq: {res.rvalue**2:.2f}"+ f" | slp : {res.slope:.2f}")
#     ax.text(x[np.abs(x).argmax()]*0.6, y[np.abs(y).argmax()]*0.6, 'r = ' + str(r[0].round(2)))
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    return res

# %%
f1, a1 = plt.subplots(1, 3)
f1.set_size_inches(24, 8)


r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[0, :], ax = a1[0], label = 'TrhACR1', 
             xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[2, :], ax = a1[0], label = 'R50CsCh', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[1, :], ax = a1[1], label = 'TrhCsCh', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[3, :], ax = a1[1], label = 'R50ACR1', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')


# plotcorr(x = 0 -g_w1118.iloc[2, :], y = g_splits.iloc[0, :], ax = a1[2], label = 'TrhVNC_CsCh', 
#              xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# plotcorr(x = 0 - g_w1118.iloc[2, :], y = g_splits.iloc[1, :], ax = a1[2], label = 'SXVNC1_CsCh', 
#          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[0, :], ax = a[1], label = 'TrhCsCh', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[2, :], ax = a[1], label = 'R50ACR1', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')

a1[0].legend()
a1[1].legend()
a1[2].legend()
a1[0].set_ylim([-2, 2])
a1[1].set_ylim([-2, 2])
a1[2].set_ylim([-2, 2])
a1[0].set_title('Fed Flies')
a1[1].set_title('Starved Flies')
a1[2].set_title('Starved Flies')
f1.tight_layout()
f1.savefig('metric_corr_48.png', dpi = 300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
f1, a = plt.subplots(3, 4)
f1.set_size_inches(12, 9)
a1=a.flatten()

r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[2, :], ax = a1[0], label = 'R50CsCh', 
             xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[0, :], ax = a1[0], label = 'NPFCsCh', 
             xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[2, :], ax = a1[0], label = 'AKH2ACR', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[0, :], ax = a1[0], label = 'TrhACR1', 
             xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[1, :], ax = a1[1], label = 'AKH3CsCh', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[3, :], ax = a1[1], label = 'R50ACR', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[1, :], ax = a1[1], label = 'TrhCsCh', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')

plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaMeta.iloc[1, :], ax = a1[2], label = 'AKH3CsCh', 
         xlabel = 'NPF', ylabel = 'AKH3CsCh')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaTrans.iloc[2, :], ax = a1[2], label = 'R50CsCh', 
         xlabel = 'NPF', ylabel = 'R50CsCh')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaTrans.iloc[1, :], ax = a1[2], label = 'TrhCsCh', 
         xlabel = 'NPF', ylabel = 'Opto')

plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaTrans.iloc[2, :], ax = a1[4], label = 'R50CsCh', 
         xlabel = 'NPF', ylabel = 'R50CsCh')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaMeta.iloc[1, :], ax = a1[5], label = 'AKH3CsCh', 
         xlabel = 'NPF', ylabel = 'AKH3CsCh')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_delta21_sorted.iloc[2, :], ax = a1[6], label = 'Starving', 
         xlabel = 'NPF', ylabel = 'Starving')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaTrans.iloc[1, :], ax = a1[7], label = 'TrhCsCh', 
         xlabel = 'NPF', ylabel = 'TrhCsCh')

plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[0, :], ax = a1[8], label = 'TrhACR', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'TrhACR')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[1, :], ax = a1[9], label = 'AKH3CsCh', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'AKH3CsCh')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[2, :], ax = a1[10], label = 'R50CsCh', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'R50CsCh')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[0, :], ax = a1[11], label = 'NPFCsCh', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'NPFCsCh')


# plotcorr(x = 0 -g_w1118.iloc[2, :], y = g_splits.iloc[0, :], ax = a1[2], label = 'TrhVNC_CsCh', 
#              xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# plotcorr(x = 0 - g_w1118.iloc[2, :], y = g_splits.iloc[1, :], ax = a1[2], label = 'SXVNC1_CsCh', 
#          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[0, :], ax = a[1], label = 'TrhCsCh', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[2, :], ax = a[1], label = 'R50ACR1', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')

a1[0].legend()
a1[1].legend()
# a1[2].legend()
for i in range(a.shape[0]):
    for j in range(a.shape[1]):
        a[i, j].set_ylim([-2.5, 4])
        a[i, j].legend()
a1[0].set_title('Fed Flies')
a1[1].set_title('Starved Flies')
# a1[2].set_title('Starved Flies')
f1.tight_layout()
# f1.savefig('metric_corr_48.png', dpi = 300)

# %%
f1, a1 = plt.subplots(1, 3)
f1.set_size_inches(24, 8)


# r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[0, :], ax = a1[0], label = 'TrhACR1', 
#              xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
# plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaTrans.iloc[1, :], ax = a1[0], label = 'TrhCsCh', 
#          xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaSplits.iloc[0, :], ax = a1[1], label = 'SXVNC1CsCh', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaSplits.iloc[1, :], ax = a1[1], label = 'SXVNC2CsCh', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')


# plotcorr(x = 0 -g_w1118.iloc[2, :], y = g_splits.iloc[0, :], ax = a1[2], label = 'TrhVNC_CsCh', 
#              xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# plotcorr(x = 0 - g_w1118.iloc[2, :], y = g_splits.iloc[1, :], ax = a1[2], label = 'SXVNC1_CsCh', 
#          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[0, :], ax = a[1], label = 'TrhCsCh', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[2, :], ax = a[1], label = 'R50ACR1', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')

a1[0].legend()
a1[1].legend()
a1[2].legend()
a1[0].set_ylim([-2, 2])
a1[1].set_ylim([-2, 2])
a1[2].set_ylim([-2, 2])
a1[0].set_title('Fed Flies')
a1[1].set_title('Starved Flies')
a1[2].set_title('Starved Flies')
f1.tight_layout()
f1.savefig('metric_corr_48.png', dpi = 300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
mean_delta21_sorted_reversed = 0-mean_delta21_sorted.iloc[[1, 2], :].rename(index={'24 hr starved': '24 hrs starved reverse', '48 hr starved': '48 hrs starved reverse'})
deltas=mean_deltaTrans.append(mean_delta21_sorted).append(mean_deltaMeta).append(mean_delta21_sorted_reversed).append(mean_deltaSplits)
# Out:
# <ipython-input-31-44ecbcf6b993>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   deltas=mean_deltaTrans.append(mean_delta21_sorted).append(mean_deltaMeta).append(mean_delta21_sorted_reversed).append(mean_deltaSplits)
# <ipython-input-31-44ecbcf6b993>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   deltas=mean_deltaTrans.append(mean_delta21_sorted).append(mean_deltaMeta).append(mean_delta21_sorted_reversed).append(mean_deltaSplits)
# <ipython-input-31-44ecbcf6b993>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   deltas=mean_deltaTrans.append(mean_delta21_sorted).append(mean_deltaMeta).append(mean_delta21_sorted_reversed).append(mean_deltaSplits)
# ...

# %%
corr = deltas.T.corr()

# mask = np.triu(np.ones_like(corr, dtype=bool))
# f, ax = plt.subplots(figsize=(4, 3))
fclu = sns.clustermap(deltas, method='single',cmap='vlag', figsize=(6, 5), vmin=3, vmax=-3)
# color_dict = {'seagreen':[0, 1],
#              'orangered':[2, 3, 4],
#              'dodgerblue':[5, 6, 7],
#              'lightblue':[8, 9, 10, 11],
#              }
# for c in color_dict.keys():
#     for i in color_dict[c]:
#         fclu.ax_heatmap.get_yticklabels()[i].set_color(c)

# %%
deltas_bash
# Out:
#                           Volume  Meal Duration  Meal Size  Duration  \
# TrhACR1                 1.300953       1.556469   1.747570  0.749470
# TrhCsCh                -1.414295      -1.335006  -1.447937 -0.334172
# baseline               -0.000002       0.001645   0.006468  0.001630
# 24 hr starved           0.718825       0.932960   0.843883  0.512500
# 48 hr starved           1.705347       1.423963   1.402231  1.343649
# 24 hrs starved reverse -0.718825      -0.932960  -0.843883 -0.512500
# 48 hrs starved reverse -1.705347      -1.423963  -1.402231 -1.343649
# TLRG                    0.314067       0.564739   0.178844  0.337424
# RLTG                   -0.952600      -0.638661  -0.682789 -0.501098
# TrhGal4TshGal80CsCh    -0.129961      -0.766921  -0.931583  0.863104
# VNCCsCh                -0.715068      -0.417363  -0.406842 -0.437277
# SXVNC1CsCh             -0.771261      -0.048632  -0.022446 -0.637824
# Trh1CsCh                0.379074       0.949706   1.146872  0.101026
# ...

# %%
deltas_bash=mean_deltaTrans.iloc[[0, 1], :].append(mean_delta21_sorted.iloc[[1, 2], :]).append(mean_delta21_sorted_reversed).append(mean_deltaSplits).append(mean_deltaBash.iloc[[0, 3, 4], :])
deltas_bash = deltas_bash.fillna(0)
# mask = np.triu(np.ones_like(corr, dtype=bool))
# f, ax = plt.subplots(figsize=(4, 3))
fclu_bash = sns.clustermap(deltas_bash, method='ward', cmap='vlag', figsize=(6, 5), )
# color_dict = {'seagreen':[0, 1],
#              'orangered':[2, 3, 4],
#              'dodgerblue':[5, 6, 7],
#              'lightblue':[8, 9, 10, 11],
#              }
# for c in color_dict.keys():
#     for i in color_dict[c]:
#         fclu_bash.ax_heatmap.get_yticklabels()[i].set_color(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 deltas_bash=mean_deltaTrans.iloc[[0, 1], :].append(mean_delta21_sorted.iloc[[1, 2], :]).append(mean_delta21_sorted_reversed).append(mean_deltaSplits).append(mean_deltaBash.iloc[[0, 3, 4], :])
#       2 deltas_bash = deltas_bash.fillna(0)
#       3 # mask = np.triu(np.ones_like(corr, dtype=bool))
#       4 # f, ax = plt.subplots(figsize=(4, 3))
#
# NameError: name 'mean_deltaTrans' is not defined

# %%
deltas_bash
# Out:
#                           Volume  Meal Duration  Meal Size  Duration  \
# TrhACR1                 1.300953       1.556469   1.747570  0.749470
# TrhCsCh                -1.414295      -1.335006  -1.447937 -0.334172
# 24 hr starved           0.718825       0.932960   0.843883  0.512500
# 48 hr starved           1.705347       1.423963   1.402231  1.343649
# 24 hrs starved reverse -0.718825      -0.932960  -0.843883 -0.512500
# 48 hrs starved reverse -1.705347      -1.423963  -1.402231 -1.343649
# TLRG                    0.314067       0.564739   0.178844  0.337424
# RLTG                   -0.952600      -0.638661  -0.682789 -0.501098
# TrhGal4TshGal80CsCh    -0.129961      -0.766921  -0.931583  0.863104
# VNCCsCh                -0.715068      -0.417363  -0.406842 -0.437277
# SXVNC1CsCh             -0.771261      -0.048632  -0.022446 -0.637824
# Trh1CsCh                0.379074       0.949706   1.146872  0.101026
# Trh4TshGal80CsCh        0.772003       0.440874   0.515284  0.148344
#
# ...

# %%
f1, a1 = plt.subplots(1, 2)
f1.set_size_inches(8, 4)


r = plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[0, :], ax = a1[0], label = 'NPFCsCh', 
             xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[1, :], ax = a1[0], label = 'AKH3CsCh', 
         xlabel = 'w1118 starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = 0- mean_delta21_sorted.iloc[2, :], y = mean_deltaMeta.iloc[2, :], ax = a1[0], label = 'AKH2ACR', 
         xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaMeta.iloc[1, :], ax = a1[1], label = 'AKH3CsCh', 
         xlabel = 'NPF', ylabel = 'AKH3CsCh')
plotcorr(x = mean_deltaMeta.iloc[0, :], y = mean_deltaTrans.iloc[2, :], ax = a1[1], label = 'R50CsCh', 
         xlabel = 'NPF', ylabel = 'R50CsCh')


# plotcorr(x = 0 -g_w1118.iloc[2, :], y = g_splits.iloc[0, :], ax = a1[2], label = 'TrhVNC_CsCh', 
#              xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# plotcorr(x = 0 - g_w1118.iloc[2, :], y = g_splits.iloc[1, :], ax = a1[2], label = 'SXVNC1_CsCh', 
#          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[0, :], ax = a[1], label = 'TrhCsCh', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')
# # plotcorr(x = 1- g_w1118.iloc[1, :], y = g_trans.iloc[2, :], ax = a[1], label = 'R50ACR1', 
# #          xlabel = 'w1118 reverse starving effect sizes', ylabel = 'opto transgene effect sizes')

a1[0].legend()
a1[1].legend()
# a1[2].legend()
# a1[0].set_ylim([-2, 2])
# a1[1].set_ylim([-2, 2])
# a1[2].set_ylim([-2, 2])
a1[0].set_title('Fed Flies')
a1[1].set_title('Starved Flies')
# a1[2].set_title('Starved Flies')
f1.tight_layout()
# f1.savefig('metric_corr_48.png', dpi = 300)

# %%
# Out:
# [Text(1, 0.5, 'R50CsCh'),
#  Text(1, 1.5, 'NPFCsCh'),
#  Text(1, 2.5, '24 hr starved'),
#  Text(1, 3.5, 'TrhACR1'),
#  Text(1, 4.5, '48 hr starved'),
#  Text(1, 5.5, 'TrhCsCh'),
#  Text(1, 6.5, '24 hrs starved reverse'),
#  Text(1, 7.5, '48 hrs starved reverse'),
#  Text(1, 8.5, 'AKH3CsCh'),
#  Text(1, 9.5, 'AKH2ACR'),
#  Text(1, 10.5, 'R50ACR1'),
#  Text(1, 11.5, 'baseline')]
