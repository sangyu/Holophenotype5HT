# %%
#| default_exp 04_Holophenotype_Dendrogram

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import svgutils
from svgutils.compose import *
import dabest
import matplotlib.pyplot as plt
import esploco.plotTools
from esploco.plotTools import setFont
setFont('Inter', 6)
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager
import matplotlib
font_dirs = ["/Users/sangyuxu/Library/Fonts"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
plt.rcParams['svg.fonttype'] = 'none'
import pickle
# %run spiral_heatmap.ipynb
import dabest
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import esploco.plotTools as plotTools
plotTools.setFont('inter', 9)
from svgutils.compose import *

paperpath = '/Users/sangyuxu/Library/Mobile Documents/com~apple~CloudDocs/EspressoManu/'
picklepath = paperpath + 'DataforFigures/Behavior/Data/pickles/'
imagepath = paperpath + 'Figures20250212/'
svgpath = imagepath+ '/SVGs/'

# %% [markdown]
# # Figure 1

# %%
# Figure1_alt
figurepath = imagepath+'/Figure1/'
Figure1 = Figure("20cm", "22cm", 
    Panel(SVG(figurepath + 'cartoons/setup.svg').scale(0.018),
    Text("A", -.2, 0.7, size=0.5, font = 'inter', weight='bold') ).move(.5, .2),

    Panel(SVG(figurepath + 'cartoons/chipcartoon.svg').scale(0.018),
    Text("B", -.2, 0.4, size=0.5, font = 'inter', weight='bold') ).move(5.5, .5),
                 
    Panel(SVG(figurepath + 'cartoons/egtrace.svg').scale(0.038),
    Text("C", 0, 0.5, size=0.5, font = 'inter', weight='bold') ).move(9.5, .4),

    Panel(SVG(figurepath + 'cartoons/starvationtimeline.svg').scale(0.018),
    Text("D", -.3, 0.2, size=0.5, font = 'inter', weight='bold') ).move(12, .7),

                 
    Panel(SVG(figurepath+'stacked_alt.svg').scale(0.03),
    Text("E", -.2, .5, size=0.5, font= 'inter', weight='bold'),
    Text("F", 10.2, .5, size=0.5, font= 'inter', weight='bold'),
    Text("G", 10.2, 3.5, size=0.5, font= 'inter', weight='bold')).move(.5, 5.6), 

    Panel(SVG(figurepath +'vWT.svg').scale(0.022),
    Text("H", -.5, .5, size=0.5, font= 'inter', weight='bold')).move(16, 5.6), 

    Panel(SVG(figurepath+'hists.svg').scale(0.03),
    Text("I", -0.2, 0, size=0.5, font= 'inter', weight='bold')).move(.5, 12.9), 

                 
    Panel(SVG(figurepath + 'Raw feed examples/Eg28_0.svg').scale(0.034),
    Text("J", -.5, .5, size=0.5, font = 'inter', weight='bold'),
    Text("K", 2, .5, size=0.5, font = 'inter', weight='bold')).move(7.5, 12.4),
                 
    Panel(SVG(figurepath + 'perifeedspeedribbon.svg').scale(0.03),
    Text("L", -0.3, 0, size=0.5, font= 'inter', weight='bold')).move(15, 12.9),

    Panel(SVG(figurepath + 'meanheatmapWT.svg').scale(0.03),
    Text("M", -1, 0.3, size=0.5, font= 'inter', weight='bold')).move(1.5, 16),
    Panel(SVG(figurepath+'hists.svg').scale(0.03),
    Text("I", -0.2, 0, size=0.5, font= 'inter', weight='bold')).move(.5, 12.9), 


    Panel(SVG(figurepath + 'fp.svg').scale(0.025),
    Text("N", -0.5, 0.3, size=0.5, font= 'inter', weight='bold')).move(9, 16),
    Panel(SVG(figurepath + 'cp.svg').scale(0.025),
    Text("O", -0.5, 0.3, size=0.5, font= 'inter', weight='bold')).move(14, 16),

    
      ).save(svgpath+"/Figure1.svg")

# %% [markdown]
# # Figure 2

# %%
figurepath = imagepath + '/Figure2/'
Figure("18cm", "24cm", 
    Panel(SVG(figurepath + 'trh_normal.svg').scale(0.01),
    Text("A", -0.4, 0, size=0.3, font = 'Inter', weight='bold'),  ).move(1, .4),
    Panel(SVG(figurepath + 'R50_normal.svg').scale(0.01),
    Text("B", -0.4, 0, size=0.3, font = 'Inter', weight='bold'),  ).move(6, .4),
    Panel(SVG(figurepath + 'starvationtimelineATR.svg').scale(0.017),
    Text("C", -0.2, 0, size=0.3, font = 'inter', weight='bold') ).move(10.5, .4),
    Panel(SVG(figurepath + 'TrhCsCh_Raster.svg').scale(0.020),
    Text("D", .6, .1, size=0.3, font = 'inter', weight='bold') ).move(0, 3.5),
    Panel(SVG(figurepath + 'TrhACR1_raster.svg').scale(0.020),
    Text("E", .6, .1, size=0.3, font = 'inter', weight='bold') ).move(5.7, 3.5),
    Panel(SVG(figurepath + 'TrhCsCh_Vcontrast.svg').scale(0.014),
    Text("F", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(13, 3.3),
    Panel(SVG(figurepath + 'TrhACR1_Vcontrast.svg').scale(0.014),
    Text("G", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(13, 7.5),
    Panel(SVG(figurepath + 'R50CsCh_raster.svg').scale(0.020),
    Text("H", .6, .1, size=0.3, font = 'inter', weight='bold') ).move(0, 11.6),
    Panel(SVG(figurepath + 'R50ACR1_raster.svg').scale(0.020),
    Text("I", .6, .1, size=0.3, font = 'inter', weight='bold') ).move(5.7, 11.6),
    Panel(SVG(figurepath + 'R50CsCh_Vcontrast.svg').scale(0.014),
    Text("J", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(13, 11.4),
    Panel(SVG(figurepath + 'R50ACR1_Vcontrast.svg').scale(0.014),
    Text("K", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(13, 15.6),
    Panel(SVG(figurepath + 'Volume.svg').scale(0.017),
    Text("L", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(1, 20),
    Panel(SVG(figurepath + 'Duration.svg').scale(0.017),
    Text("M", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(5, 20),
    Panel(SVG(figurepath + 'Meal Size.svg').scale(0.017),
    Text("N", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(9, 20),
    Panel(SVG(figurepath + 'Count.svg').scale(0.017),
    Text("O", -0.2, 0.3, size=0.3, font = 'inter', weight='bold') ).move(13, 20),
    # Panel(SVG(panelpath + 'Duration.svg').scale(0.015),
    # Text("m", -0.1, 0.2, size=0.3, font = 'inter', weight='bold') ).move(4.5, 12.5),
    # Panel(SVG(panelpath + 'Meal Size.svg').scale(0.015),
    # Text("n", -0.1, 0.2, size=0.3, font = 'inter', weight='bold') ).move(8, 12.5),
    # Panel(SVG(panelpath + 'Count.svg').scale(0.015),
    # Text("o", -0.1, 0.2, size=0.3, font = 'inter', weight='bold') ).move(11.5, 12.5),       
       # Panel(SVG(panelpath + 'TrhACR1_raster.svg').scale(0.015),
    # Text("e", 0.2, 0.1, size=0.3, font = 'inter', weight='bold') ).move(9.5, .4),
    # Panel(SVG(panelpath + 'R50CsCh_raster.svg').scale(0.015),
    # Text("f", 0.2, 0.1, size=0.3, font = 'inter', weight='bold') ).move(5, 5),
    # Panel(SVG(panelpath + 'R50ACR1_raster.svg').scale(0.015),
    # Text("g", 0.2, 0.1, size=0.3, font = 'inter', weight='bold') ).move(9.5, 5),
       
    ).save(svgpath+"/Figure2_5HTFeeding.svg")

# %% [markdown]
# # Figure S1

# %%
figurepath = imagepath + '/FigureS1/'

Figure("16cm", "4cm", 
    Panel(SVG(figurepath + 'TrhCsChF_Vcontrast.svg').scale(0.014),
    Text("A", -.3, .3, size=0.3, font = 'inter', weight='bold') ,    
    # Text("5HT Optogenetic Effects in Females", 0, -.4, size=0.3, font = 'inter', weight='medium')
         ).move(1, 0),

    Panel(SVG(figurepath + 'TrhACRF_Vcontrast.svg').scale(0.014),
    Text("B", -.3, .3, size=0.3, font = 'inter', weight='bold') ).move(6, 0),
    Panel(SVG(figurepath + 'R50CsChF_Vcontrast.svg').scale(0.014),
    Text("C", -.3, .3, size=0.3, font = 'inter', weight='bold') ).move(11, 0),
    ).save(svgpath+"/FigureS1_Female.svg")

# %% [markdown]
# # Figure 3

# %%
figurepath = imagepath + '/Figure3/'

Figure("16cm", "12cm", 
    Panel(SVG(figurepath + 'heatmap_trhcsch.svg').scale(0.03),
    Text("A", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(1, 0.5),
    Panel(SVG(figurepath + 'heatmap_trhAcr.svg').scale(0.03),
    Text("B", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(8, 0.5),
    Panel(SVG(figurepath + 'heatmap_R50H05csch.svg').scale(0.03),
    Text("C", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(1, 4),
    Panel(SVG(figurepath + 'heatmap_R50H05acr.svg').scale(0.03),
    Text("D", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(8, 4),
    Panel(SVG(imagepath+'/Figure2/' + 'Height.svg').scale(0.015),
    Text("E", 0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(1, 8.5),
    Panel(SVG(imagepath+'/Figure2/' + 'Latency.svg').scale(0.015),
    Text("F",0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(4.5, 8.5),
    Panel(SVG(imagepath+'/Figure2/' + 'Speed.svg').scale(0.015),
    Text("G",0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(8, 8.5),
    Panel(SVG(imagepath+'/Figure2/' + 'Perifeed Speed Ratio.svg').scale(0.015),
    Text("H",0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(11.5, 8.5),
        ).save(svgpath+"/Figure3_5HTloco.svg")

# %% [markdown]
# # Figure S2

# %%
figurepath = imagepath + '/FigureS2/'

Figure("12cm", "10cm", 
    Panel(SVG(imagepath+'/Figure2/' + 'Falls.svg').scale(0.015),
    Text("A",  -.3, 0, size=0.3, font = 'Inter', weight='bold') ,
         ).move(1,.5),
    Panel(SVG('/Users/sangyuxu/Library/Mobile Documents/com~apple~CloudDocs/EspressoManu/Figures20250212/Figure1/spWT.svg').scale(0.015),
    Text("C",  -0.7, 0, size=0.3, font = 'Inter', weight='bold') ,
         ).move(8.5,.5),
    Panel(SVG(figurepath+ 'R50CsCh_XyVcontrast.svg').scale(0.015),
    Text("B",  -.3, 0, size=0.3, font = 'Inter', weight='bold') ,
         ).move(4,.5),
    Panel(SVG(figurepath + 'cartoons/nofood.svg').scale(0.023),
    Text("D", .7, .8, size=0.3, font = 'inter', weight='bold') ).move(0, 5),
    Panel(SVG(figurepath + 'R50CsChNoFood_Speedcontrast.svg').scale(0.014),
    Text("E",0, 0.3, size=0.3, font = 'inter', weight='bold'),
         ).move(4.5, 5.5),

    ).save(svgpath+"/FigureS2_Loco.svg")

# %% [markdown]
# # Figure 4

# %% [markdown]
# Assembled in ai

# %% [markdown]
# # Figure S3

# %% [markdown]
# Assembled in ai

# %% [markdown]
# # Figure S4

# %%
figurepath = imagepath + '/FigureS4/'

Figure("18cm", "17cm", 
    Panel(SVG(figurepath + 'RLTG_Vcontrast.svg').scale(0.025),
    Text("A",  -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(1.3, 1),
    Panel(SVG(figurepath + 'TLRG_Vcontrast.svg').scale(0.025),
    Text("B", -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(7, 1),
    Panel(SVG(figurepath + 'TrhBrainCsCh_Vcontrast.svg').scale(0.025),
    Text("C", -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(12.7, 1),
    Panel(SVG(figurepath + 'TrhVNCCsCh_Vcontrast.svg').scale(0.025),
    Text("D",  -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(1.3, 8),
    Panel(SVG(figurepath + 'TrhVNCACR1_Vcontrast.svg').scale(0.025),
    Text("E", -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(7, 8),
    Panel(SVG(figurepath + 'TrhVNCACR1_MScontrast.svg').scale(0.025),
    Text("F",  -1.1, .4, size=0.5, font = 'Inter', weight='bold') ).move(12.7, 8),
    ).save(svgpath+"/FigureS4_SubpopContrasts.svg")

# %% [markdown]
# # Figure 5

# %%
from svgutils.compose import *
figurepath = imagepath + '/Figure5/'

Figure("20cm", "28cm", 
    Panel(SVG('/Users/sangyuxu/Library/Mobile Documents/com~apple~CloudDocs/EspressoManu/Figures20240202/Figure1/metricForest.svg').scale(0.028),
    Text("A", 0, 0.5, size=0.5, font = 'inter', weight='bold'), 
    Text("D", 0, 11, size=0.5, font = 'inter', weight='bold')
         ).move(.5, 0),
    Panel(SVG(figurepath + 'Trhntransgenic_ribbon_xaxis.svg').scale(0.020),
    Text("B", 1, .5, size=0.5, font = 'inter', weight='bold') ).move(-0.5, 6),
    Panel(SVG(figurepath + 'R50H05transgenic_ribbon_xaxis.svg').scale(0.020),
    Text("C", 1, .5, size=0.5, font = 'inter', weight='bold') ).move(9.5, 6),

    # Panel(SVG(figurepath + 'ClusterCorrelation.svg').scale(0.025),
    # Text("B", 0, 2, size=0.5, font = 'inter', weight='bold') ).move(0.2, 7.5),
    ).save(svgpath+"/Figure5_CorrelationClustering.svg")

# %% [markdown]
# # Figure S5

# %%
figurepath = imagepath + '/Figure1/'

Figure("21cm", "17cm", 
    Panel(SVG(figurepath + 'corr_all.svg').scale(0.026),
    Text("A", 1, 0.2, size=0.5, font = 'inter', weight='bold') ).move(-0.5, 0.8),
    Panel(SVG(figurepath + 'cooreg.svg').scale(0.033),
    Text("B", 0.4, 0.2, size=0.5, font = 'inter', weight='bold'), 
    Text("C", 4.5, 0.2, size=0.5, font = 'inter', weight='bold') , 
    Text("D", 8.1, 0.2, size=0.5, font = 'inter', weight='bold'),  
    Text("E", 0.4, 3.8, size=0.5, font = 'inter', weight='bold'),  
    Text("F", 4.5, 3.8, size=0.5, font = 'inter', weight='bold'),  
    Text("G", 8.1, 3.8, size=0.5, font = 'inter', weight='bold'),  ).move(9, 0.8),
    Panel(SVG(figurepath + 'corr_0.svg').scale(0.02),
    Text("H", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(0, 8),
    Panel(SVG(figurepath + 'corr_24.svg').scale(0.02),
    Text("I", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(6, 8),
    Panel(SVG(figurepath + 'corr_48.svg').scale(0.02),
    Text("J", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(12, 8),
    Panel(SVG(figurepath + 'corr_contrast.svg').scale(0.015),
    Text("K", -1, 0.5, size=.5, font = 'inter', weight='bold') ).move(2, 13),
    Panel(SVG(figurepath + 'componentsexplained.svg').scale(0.03),
    Text("L", 0.2, 0, size=0.5, font = 'inter', weight='bold') ).move(7, 13.5),
      ).save(svgpath+"/FigureS5_SupplementalEthomics.svg")

# %% [markdown]
# # Figure S6

# %%
figurepath = imagepath + '/FigureS6/'

Figure("24cm", "26cm", 
    Panel(SVG(figurepath + 'corrMatrix_48.svg').scale(0.028),
    Text("A", 0.5, 0, size=0.5, font = 'inter', weight='bold'),
    Text("B", 12, 0, size=0.5, font = 'inter', weight='bold') ).move(0, 1),
    Panel(SVG(figurepath + 'Trhntransgenic_ribbon.svg').scale(0.023),
    Text("C", 0.5, .5, size=0.5, font = 'inter', weight='bold') ).move(0, 6.5),
    Panel(SVG(figurepath + 'R50H05transgenic_ribbon.svg').scale(0.023),
    Text("D", 0.5, .5, size=0.5, font = 'inter', weight='bold') ).move(11.5, 6.5),
    Panel(SVG(figurepath + 'Trhn-VNCtransgenic_ribbon.svg').scale(0.023),
    Text("E", 0.5,.5, size=0.5, font = 'inter', weight='bold') ).move(0, 11),
    Panel(SVG(figurepath + 'AKHtransgenic_ribbon.svg').scale(0.023),
    Text("F", 0.5, .5, size=0.5, font = 'inter', weight='bold') ).move(11.5, 10.5),
    Panel(SVG(figurepath + 'NPFtransgenic_ribbon_xaxis.svg').scale(0.023),
    Text("G", 0.5, .5, size=0.5, font = 'inter', weight='bold') ).move(0, 14.5),
    Panel(SVG(figurepath + 'Ilp2transgenic_ribbon_xaxis.svg').scale(0.023),
    Text("H", 0.5,.5, size=0.5, font = 'inter', weight='bold') ).move(11.5, 14.5),
    Panel(SVG(figurepath + 'scatter1.svg').scale(0.028),
    Text("I", 0.5,0, size=0.5, font = 'inter', weight='bold'),
    Text("J", 6, 0, size=0.5, font = 'inter', weight='bold'),
    Text("K", 11.5, 0, size=0.5, font = 'inter', weight='bold'),
    Text("L", 17, 0, size=0.5, font = 'inter', weight='bold')
         ).move(1, 20),
    ).save(svgpath+"/FigureS6_SuppMetaRibbon.svg")

# %% [markdown]
# # Figure 6

# %%
figurepath = imagepath + '/Figure6/'

Figure("18cm", "18cm", 
    Panel(SVG(figurepath +'/Trhi.svg').scale(0.023),
    Text("E", 0.7, .4, size=0.4, font = 'inter', weight='bold')).move(7, .3),
    Panel(SVG(figurepath +'/5htnorm.svg').scale(0.020),
    Text("A", 0, .2, size=0.4, font = 'inter', weight='bold'), 
    Text("B", 4, .2, size=0.4, font = 'inter', weight='bold'),
    Text("C", 0, 5.2, size=0.4, font = 'inter', weight='bold'),
    Text("D", 4, 5.2, size=0.4, font = 'inter', weight='bold'),
         ).move(0, .5),
    Panel(SVG(figurepath +'/brainsimple.svg').scale(0.0015)).move(1,1.5),
    Panel(SVG(figurepath +'/vncsimple.svg').scale(0.0015)).move(4.8, 1.5),

    Panel(SVG(figurepath +'/trhsimple.svg').scale(0.0015)).move(9.9, 1.3),
    Panel(SVG(figurepath +'/vncsimple.svg').scale(0.0015)).move(9.9 + 2.55, 1.3),

    Panel(SVG(figurepath +'/GlutSutRNAi.svg').scale(0.023),
    Text("F", 0, .2, size=0.4, font = 'inter', weight='bold'),
    ).move(0, 8),
    Panel(SVG(figurepath +'/trhsimple.svg').scale(0.0015)).move(1 + 2.3, 7.5+1.5),
    Panel(SVG(figurepath +'/vncsimple.svg').scale(0.0015)).move(1 + 2.3*2, 7.5+1.5),
    Panel(SVG(figurepath +'/trhsimple.svg').scale(0.0015)).move(1 + 2.3*3, 7.5+1.5),
    Panel(SVG(figurepath +'/vncsimple.svg').scale(0.0015)).move(1 + 2.3*4, 7.5+1.5),

    Panel(SVG(figurepath + '/scatter2.svg').scale(0.017),
    Text("G", 0, .2, size=0.4, font = 'inter', weight='bold'),
    ).move(13, 8),
).save(svgpath + "Figure6_RNAi.svg")

# %% [markdown]
# # Figure 3

# %% [markdown]
# # Figure Ethomics

# %% [markdown]
# # Supplemental Ethomics

# %%
## from svgutils.compose import *
figurepath = imagepath + '/Figure1/'

Figure("21cm", "17cm", 
    Panel(SVG(figurepath + 'corr_all.svg').scale(0.026),
    Text("A", 1, 0.2, size=0.5, font = 'inter', weight='bold') ).move(-0.5, 0.8),
    Panel(SVG(figurepath + 'cooreg.svg').scale(0.033),
    Text("B", 0.4, 0.2, size=0.5, font = 'inter', weight='bold'), 
    Text("C", 4.5, 0.2, size=0.5, font = 'inter', weight='bold') , 
    Text("D", 8.1, 0.2, size=0.5, font = 'inter', weight='bold'),  
    Text("E", 0.4, 3.8, size=0.5, font = 'inter', weight='bold'),  
    Text("F", 4.5, 3.8, size=0.5, font = 'inter', weight='bold'),  
    Text("G", 8.1, 3.8, size=0.5, font = 'inter', weight='bold'),  ).move(9, 0.8),
    Panel(SVG(figurepath + 'corr_0.svg').scale(0.02),
    Text("H", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(0, 8),
    Panel(SVG(figurepath + 'corr_24.svg').scale(0.02),
    Text("I", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(6, 8),
    Panel(SVG(figurepath + 'corr_48.svg').scale(0.02),
    Text("J", 0.4, 0.2, size=.5, font = 'inter', weight='bold') ).move(12, 8),
    Panel(SVG(figurepath + 'corr_contrast.svg').scale(0.015),
    Text("K", -1, 0.5, size=.5, font = 'inter', weight='bold') ).move(2, 13),
    Panel(SVG(figurepath + 'componentsexplained.svg').scale(0.03),
    Text("L", 0.2, 0, size=0.5, font = 'inter', weight='bold') ).move(7, 13.5),
      ).save(svgpath+"/FigureSupplementalEthomics.svg")

# %%
## from svgutils.compose import *

Figure("22cm", "30cm", 
    Panel(SVG(figurepath + 'corr_0.svg').scale(0.030),
    Text("A", 0.2, 0.2, size=.5, font = 'inter', weight='bold') ).move(0, 1),
    Panel(SVG(figurepath + 'corr_24.svg').scale(0.030),
    Text("B", 0.2, 0.2, size=.5, font = 'inter', weight='bold') ).move(11, 1),
    Panel(SVG(figurepath + 'corr_48.svg').scale(0.030),
    Text("C", 0.2, 0.2, size=.5, font = 'inter', weight='bold') ).move(0, 10),
    Panel(SVG(figurepath + 'cooreg.svg').scale(0.030),
    Text("D", 0.2, 0.2, size=0.5, font = 'inter', weight='bold'), 
    Text("E", 4.2, 0.2, size=0.5, font = 'inter', weight='bold') , 
    Text("F", 8.2, 0.2, size=0.5, font = 'inter', weight='bold'),  
    Text("G", 0.2, 4.2, size=0.5, font = 'inter', weight='bold'),  
    Text("H", 4.2, 4.2, size=0.5, font = 'inter', weight='bold'),  
    Text("I", 8.2, 4.2, size=0.5, font = 'inter', weight='bold'),  ).move(11,10),
    Panel(SVG(figurepath + 'corr_contrast.svg').scale(0.020),
    Text("J", -1, 1, size=.5, font = 'inter', weight='bold') ).move(1.2, 18),
    Panel(SVG(figurepath + 'componentsexplained.svg').scale(0.040),
    Text("K", 0.2, 0, size=0.5, font = 'inter', weight='bold') ).move(6, 20),
      ).save(svgpath+"/Figure2Supp1.svg")

# %%
# %history -g -f history.txt'
# Out:
# #Figure 4
# from svgutils.compose import *
#
# Figure("14.5cm", "13cm",
#     Panel(SVG(panelpath + 'heatmap_trhcsch.svg').scale(0.03),
#     Text("A", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(0.5, 0.5),
#     Panel(SVG(panelpath + 'heatmap_trhAcr.svg').scale(0.03),
#     Text("B", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(7.5, 0.5),
#     Panel(SVG(panelpath + 'heatmap_R50H05csch.svg').scale(0.03),
#     Text("C", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(0.5, 4),
#     Panel(SVG(panelpath + 'heatmap_R50H05acr.svg').scale(0.03),
#     Text("D", 0, 0.4, size=0.4, font = 'inter', weight='bold') ).move(7.5, 4),
#     Panel(SVG(panelpath + 'Height.svg').scale(0.015),
#     Text("E", 0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(0.5, 8.5),
#     Panel(SVG(panelpath + 'Latency.svg').scale(0.015),
#     Text("F",0, 0.2, size=0.4, font = 'inter', weight='bold') ).move(4, 8.5),
#     Panel(SVG(panelpath + 'Speed.svg').scale(0.015),
# ...
